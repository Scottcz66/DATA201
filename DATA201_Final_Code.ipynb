# %%
# STEP 1: Install required packages

# this section is just gettign all of the liabarys that are needed
install.packages('tidyverse')
install.packages('polite')
install.packages('xml2')
install.packages('purrr')
install.packages('glue') 
install.packages('rvest')

library(tidyverse)
library(polite) # this library is jsut a better version of the rvest library 
library(xml2) # makes it easier to work with HTML and XML from R
library(purrr) # to work with lists and map functions
library(glue) # to paste strings
library(rvest) # rvest makes scraping easier
# Out:
# Warning message:
# "package 'tidyverse' is in use and will not be installed"
# Warning message:
# "package 'polite' is in use and will not be installed"
# Warning message:
# "package 'xml2' is in use and will not be installed"
# Warning message:
# "package 'purrr' is in use and will not be installed"
# Warning message:
# "package 'glue' is in use and will not be installed"
# Warning message:
# "package 'rvest' is in use and will not be installed"

# %%
# The Neat Places website URL
url <- "https://neatplaces.co.nz/places/christchurch-canterbury/eat-drink/cafes"

# The Neat Places website HTML
page <- read_html(url)

# Vector of Christchurch cafe names
# Scans the page HTML for the specified node and returns the text
cafe_name <- page %>% 
   html_nodes(".list-item-title") %>% 
   html_text()

# Dataframe of Christchurch cafe names
cafe_names <- tibble(cafe_name)

# Vector of Christchurch cafe descriptions
summary <- page %>%
  html_nodes(".summary") %>%
  html_text()

# Vector of links to each of the cafes
# Searches for specified node and HREFhref attribute to get links
link <- page %>% 
  html_nodes(".list-item a") %>% 
  html_attr('href')

# Dataframe of cafe names and related page link
link_table <- tibble(cafe_name, link)

# %%
# Function which outputs data for different places in nz as a search option
# Takes in a city in NZ and returns its avalable cafes
change_place <- function(place_name) {
    # Converts given place name to URL format
    url_name <- place_name %>%
        tolower() %>% 
        str_replace_all(" & ", "-") %>%
        str_replace_all(" ", "-") %>%
        str_replace_all("ō", "o") %>%
        str_replace_all("ā", "a")
    
    # The generated URL
    new_url <- glue("https://neatplaces.co.nz/places/{url_name}/eat-drink/cafes") 

    # The page HTML of the generated URL
    page <- read_html(new_url) 
    
    # Vector of the cafe names
    cafe_data <- page %>% 
        html_nodes(".list-item-title p") %>%
        html_text()

    return(cafe_data)
}

# %%
# The AudioCulture website in html
audio_culture_page = read_html("https://www.audioculture.co.nz/music_index?category=Person")

# Profile names
Profiles = audio_culture_page %>% html_nodes(".skippy-col-link") %>% html_text()

# Profile links
Links = audio_culture_page %>% html_nodes(".skippy-col-link") %>% html_attr('href')

# Dataframe of profile and associated link
df = data.frame(Profiles, Links)

# %%
# Prints NZ music profiles based on chars of given string
create_profile_list = function(cafe_name) {
    # Removes special symbols and whitespace from string
    cleaned_string = gsub("([^A-Za-z0-9])+", "", 
        cafe_name %>% 
        str_replace_all("é", "e") %>%
        str_replace_all("ō", "o") %>%
        str_replace_all("ā", "a"))

    # Splits string into list for iteration
    char_list = strsplit(cleaned_string, "")[[1]]

    # The list of NZ profiles based on cafe name
    profile_list = data.frame()
    
    # Iterate through every char in the given string
    for (char in char_list) {
        # Converts char into upper case for REGEX pattern
        upper_char = toupper(char)

        # Converts char into lower case for REGEX pattern
        lower_char = tolower(char)

        # Creates list of profiles that match REGEX pattern (Starts with given char)
        match_list = grep(glue('^[{upper_char}{lower_char}]'), Profiles, value = TRUE)
        
        # If the match list is not empty choose random profile from match list
        if (length(match_list) != 0) {
                
            # Does at most 5 attempts to find at least 1 album from a profile
            for (i in 1:5) {
                # Randomly selected profile
                profile_match = sample(match_list, 1)

                # The profile's discography
                profile_discography = get_discography(profile_match)
                
                if (nrow(profile_discography) >= 1) {
                    break()
                }
            }

            # Sometimes profiles have empty discographies
            if (nrow(profile_discography) == 0) {
                profile_album = data.frame(Character = upper_char, 
                                           Profile = profile_match, 
                                           Album = NA_character_, 
                                           Featuring = NA_character_, 
                                           Year = NA_real_)
            } else {
                # profile_album_index = match(profile_discography[3] >= 2010)[2]


                # Randomly selects album index from discography
                profile_album_index = sample(nrow(profile_discography), 1) 

                # Create data frame entry for profile_lsit
                profile_album = merge((data.frame(Character = upper_char, Profile = profile_match)), 
                                      (profile_discography[profile_album_index,]))
            }
            
        } else {
            # If no match, create empty data frame entry for profile_list
            profile_album = data.frame(Character = upper_char, 
                                       Profile = NA_character_, 
                                       Album = NA_character_, 
                                       Featuring = NA_character_, 
                                       Year = NA_real_)
        }

        # Appends profile_list with new profile
        profile_list = rbind(profile_list, profile_album)
    }

    return(profile_list)
}

# %%
# Takes a profile name as input
# Returns given name's discography (currenly no error handling if name not in dataframe)
get_discography = function(name) {
    name_link = (df %>% filter(str_detect(Profiles, name)))[[2]][1]
    
    profile_discography_page = glue('https://www.audioculture.co.nz{name_link}/discography') %>% read_html()

    Album     = profile_discography_page %>% html_nodes("[class='header']") %>% html_text()
    Featuring = profile_discography_page %>% html_nodes("[class='body']")   %>% html_text()
    Year      = profile_discography_page %>% html_nodes("[class='year']")   %>% html_text() %>% as.numeric()
    
    # Replaces empty entries with NA
    Album[Album == ""] = NA_character_

    # Replaces empty entries with NA
    Featuring[Featuring == ""] = NA_character_

    # If the year length is less than 1000, replace with NA
    Year[Year < 1000] = NA_real_
    
    # Data frame of the given profile's discography
    discography_df = data.frame(Album, Featuring, Year)

    return(discography_df %>% filter(Year >= 1000))
}

# %%
# STEP 2: Select the index of the cafe you would like a playlist of

# Dataframe of Christchurch cafes to select from
chch_cafes_df = data.frame(Index = 1:nrow(cafe_names), Cafe = cafe_names, Summary = summary)
chch_cafes_df
# Out:
#    Index cafe_name
# 1   1    \nMind Your Temper\n
# 2   2    \nChild Sister\n
# 3   3    \nTom's\n
# 4   4    \nBonobo Café\n
# 5   5    \nThe Old Vicarage\n
# 6   6    \nGeneral Post\n
# 7   7    \nTruffle Café\n
# 8   8    \nThe Mediterranean Food Company\n
# 9   9    \nAddington Coffee Co-op\n
# 10 10    \nSix Ounces\n
# 11 11    \nMona Vale Homestead & Pantry\n
# 12 12    \nNiche Coffee + Eatery\n
# 13 13    \nNative Café\n
# 14 14    \nSouth Town Club\n
# 15 15    \nSaturdays\n
# 16 16    \nBarefoot Eatery\n
# 17 17    \nLittle River Café and Store\n
# 18 18    \nRollickin' Gelato Cashel Street\n
# 19 19    \nAlly & Sid\n
# 20 20    \nFoundation Café\n
# 21 21    \nGelato & Tea\n
# 22 22    \nThe Welder\n
# 23 23    \nRiverside Market\n
# 24 24    \nSweet Soul Patisserie\n
# 25 25    \nEvil Genius Bar & Eatery\n
# 26 26    \nJ'aime les Macarons\n
# 27 27    \nOld School Collective\n
# 28 28    \nGrater Goods\n
# 29 29    \nWestend Stories\n
# 30 30    \nSwitch New Brighton\n
# 31 31    \nPrima Roastery\n
# 32 32    \nDux Dine\n
# 33 33    \nLittle Poms\n
# 34 34    \nThe Birdwood\n
# 35 35    \nThe Arts Centre\n
# 36 36    \nBOXed Quarter\n
# 37 37    \nMiro\n
# 38 38    \nLittle Vintage Espresso\n
# 39 39    \nAllpress Espresso\n
# 40 40    \nCoffee Embassy\n
# 41 41    \nLyttelton Coffee Company\n
# 42 42    \nThe Origin\n
# 43 43    \nDispense Espresso\n
# 44 44    \nPark Ranger\n
# 45 45    \nPeninsula General Store\n
# 46 46    \nUnknown Chapter\n
# 47 47    \nRollickin' Gelato\n
# 48 48    \nDose Diner\n
# 49 49    \nHerba Gourmet\n
#    Summary
# 1  \nIf you’re feeling grumpy or a little blue, a visit to Mind Your Temper is sure to lighten your mood.\n
# 2  \nSeeking a calm environment with aesthetically-pleasing interior decor, complete with incredible coffee and delicious food to match? Then look no further, Child Sister has...\n
# 3  \nIf you are a sando aficionado and find yourself in the South Town area of Christchurch city centre, keep an eye out for the striking cobalt blue hue of Tom’s.\n
# 4  \nBonobo: a benevolent primate, a trip-hop artist and more recently a plant-based cuisine destination in the seaside suburb of Sumner.\n
# 5  \nThe Old Vicarage is exactly that, the former home of the Vicars from St Mary’s Church in Halswell.\n
# 6  \nYou’ll find a few golden nuggets interspersed around Tai Tapu, and General Post is one of them.\n
# 7  \nYou may think of truffle as clandestine but this Merivale café - with the same name - is anything but.\n
# 8  \n Down the industrial eastern end of Tuam Street in an old brickery is a secluded slice of Italy.\n
# 9  \nAddington Coffee Co-op is, simply put, a true Christchurch institution with laid-back vibes and house-roasted coffee.\n
# 10 \nThere’s nothing quite like a cosy neighbourhood haunt and six ounces is exactly that.\n
# 11 \nMona Vale Homestead & Pantry in Christchurch creates an idyllic setting for a beautifully appointed restaurant, perched along the Avon River.\n
# 12 \nNiche Coffee + Eatery, the latest addition to the hospitality scene of Sumner, fits like a glove to the seaside village.\n
# 13 \nNext time you find yourself Sydenham side of Christchurch town, stop at Native Café for a cup of top-notch coffee and an honest bite to eat.\n
# 14 \nSouth Town Club is a sweet collab between the old owner’s Supreme and Dan Hobson, an absolute champion of top-notch hospitality.\n
# 15 \nSaturdays is a celebration of not just the weekend, but every day. It’s an ode to what saturdays stand for: slowing down, enjoying one another and pairing it all with excellent food and drink.\n
# 16 \nGrab your mates, your mum, your bubs and even your dog, and head down to Barefoot Eatery at The Welder to discover a nourishing and fun café experience.\n
# 17 \nThis institutional café, specialising in homemade fare for all, is well worth a visit next time you're passing through Little River.\n
# 18 \nRollickin' Gelato brings a fabulous late-night dessert venue to the riverside end of Cashel St.\n
# 19 \nEverything about Ally & Sid is inviting - a breezy spot for excellent coffee, tasty cabinet fare and a big side of sunshine.\n
# 20 \nFoundation is fully licensed, serving up flavoursome fare seamlessly integrated into Otautahi’s world-class library, Tūranga.\n
# 21 \nGelato & Tea offers homemade gelato and a range of tea drinks, alongside a selection of delicious sweet treats.\n
# 22 \nThe Welder is a unique health and wellbeing centre in stunningly repurposed buildings in the heart of South Town.\n
# 23 \nThis unique Christchurch establishment brings fresh produce, artisan bakeries, independent food stalls, rooftop bars and restaurants, high-class retail and eclectic market stalls all under one roof.\n
# 24 \nThis light-filled corner shop is the first fine patisserie shop in Christchurch.\n
# 25 \nEvil Genius Bar & Eatery is a destination you need to get to know. Open from dawn ‘til way past dusk, offering everything from coffee to cocktails.\n
# 26 \nHundreds of colourful macarons with punchy and interesting flavours are produced out of the J’aime les macarons kitchen each day.\n
# 27 \nThis collective of lifestyle businesses in North Canterbury has turned a 140-year-old school into a dream destination just north of Christchurch.\n
# 28 \nFound in an old glass factory in Sydenham’s industrial blocks, you'll find everything from sausages to bacon and steak - just the more humane and sustainable kind.\n
# 29 \nWestend Stories is a green oasis for those looking to temporarily escape the confines of their workplace.\n
# 30 \nSwitch is a bit of an institution of the seaside suburb of New Brighton.\n
# 31 \nWhether you’re after a caffeine kick, a cool spot for a catch up, a resupply of beans or a new espresso machine, Prima is the place - they’ve got parking out the back, too.\n
# 32 \nDux Dine is one of those rare gems where anyone and everyone has a place at the table, all in a cosy, home-like atmosphere.\n
# 33 \nLocated in the same building as the ever-popular Pomeroy’s Old Brewery Inn, Little Poms is charming neighbourhood café all about good food made by Christchurch’s talented producers and artisans.\n
# 34 \nMuch-loved neighbourhood cafe by day, knock-out contemporary Italian eatery by night – The Birdwood might just be the dream local hospo joint.\n
# 35 \nA much-loved heritage hub for all things creative and cultural, Christchurch’s Arts Centre is a real jewel in the city’s crown.\n
# 36 \nA hub for all things food, creativity and culture, BOXed Quarter thinks outside the square.\n
# 37 \nA stylish and cosy spot for breakfast, lunch or brunch any day of the week.\n
# 38 \nA jewel in the Amberley crown, Little Vintage Espresso offers delicious homemade food and good coffee.\n
# 39 \nThe coffee here is just what you'd expect from the experienced Allpress roasters.\n
# 40 \nThis flagship café is the best place to try adventurous coffee coupled with house-made lunches and coffee accompaniments like their delicious doughnuts.\n
# 41 \nA quirky place humming with activity, this place is home to a coffee roastery and a cafe big on sustainability, community and authentic fare.\n
# 42 \nVegetarian cafe The Origin brings a much needed boost to the hospitality scene in St Albans to the delight of locals.\n
# 43 \nDispense Espresso’s owner, Hamish Bell, knows a thing or two about what makes a café great.\n
# 44 \nA café that hasn’t missed a beat when it comes to the details, and one of the best to have opened its doors in the city.\n
# 45 \nDon’t be fooled by the vintage exterior of this cafe, deli and gourmet food store — inside you'll find the most modern of cuisine philosophies.\n
# 46 \nA sunny spot always bustling with life thanks to its epic brunch menu, homemade slices and cakes and speciality roasted coffee.\n
# 47 \nHouse made organic milk gelatos and sorbets mean Rollickin’ is the talk of the town.\n
# 48 \nAdding a much needed touch of ‘cool’ to Blenheim Road, Dose Diner takes a page from the book of the quirky Melbourne café scene.\n
# 49 \nIf you thought fast food was served greasy treats, think again. Herba Gourmet has rethought street food to bring fresh, healthy, fine food to diners on the go.\n

# %%
# STEP 3: Set the index value below to the cafe you desire

# E.g. Herba Gourmet has index 49
index = 49

# %%
# STEP 4: Run this code to generate a random playlist
selected_cafe = chch_cafes_df[[2]][index]
create_profile_list(selected_cafe)
# Out:
#    Character Profile             Album
# 1  H         Headband            Love Is Bigger Than The Whole Wide World
# 2  E         Edward Castelow     Mufti Day
# 3  R         Ragnarok            Ragnarok
# 4  B         Broods              Broods
# 5  A         Alastair Dougal     Somewhere In New Zealand Tonight
# 6  G         Gentle Annie        The Devil Went Down To Auckland
# 7  O         OMC                 How Bizarre
# 8  U         Urban Disturbance   37 Degrees Lattitude
# 9  R         Rochelle Vinsen     I Like Your Kind Of Love
# 10 M         Mahinaarangi Tocker Hei Ha!
# 11 E         Enemy, The          The Enemy At The Beneficiaries
# 12 T         Tommy Adderley      Hooray For The Salvation Army Band
#    Featuring                        Year
# 1  Headband                         1972
# 2  Dictaphone Blues                 2014
# 3  Ragnarok (4)                     1975
# 4  Broods                           2014
# 5  Glen Moffatt                     1995
# 6  Gentle Annie                     1982
# 7  OMC                              1995
# 8  Urban Disturbance (3)            1994
# 9  Jim McNaught And Rochelle Vinsen 1963
# 10 Mahinarangi Tocker               2002
# 11 Enemy, The (3)                   2001
# 12 Adderley Walker Movement         1970
